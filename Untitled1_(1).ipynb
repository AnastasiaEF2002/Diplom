# %%
import os
import pandas as pd

import torch
from torch.utils.data import DataLoader
from torchvision import transforms as T
from PIL import Image
from typing import List

df = pd.read_csv(os.path.join(os.getcwd(), "/content/AI_index_db.csv"))
df.head(200)
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 1                      China   16.51          100.00                  91.57
# 2             United Kingdom   39.65           71.43                  74.65
# 3                     Canada   31.28           77.05                  93.94
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 57                 Sri Lanka    6.27           34.64                  35.79
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 60                   Nigeria    2.74            0.00                  50.10
# 61                  Pakistan    8.00            2.43                  12.48
#
# ...

# %%
final = pd.ExcelWriter('AI index.xlsx')
df.to_excel(final, index=False)

final.save()
# Out:
# <ipython-input-2-b292f52a995e>:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   final.save()

# %% [markdown]
# Индикатор талантов фокусируется на наличии квалифицированных специалистов-практиков для предоставления решений в области искусственного интеллекта.
#
# Индикатор инфраструктуры фокусируется на надежности и масштабе инфраструктуры доступа, от электроснабжения и Интернета до сверхвысоких вычислительных возможностей.
#
# Индикатор операционной среды фокусируется на нормативно-правовом контексте и общественном мнении, связанном с искусственным интеллектом.
#
# Исследовательский показатель фокусируется на масштабах специализированных исследований и самих исследователях; исследуется количество публикаций и цитирований в заслуживающих доверия академических журналах.
#
# Индикатор развития фокусируется на разработке фундаментальных платформ и алгоритмов, на которые опираются инновационные проекты в области искусственного интеллекта.
#
# Индикатор государственной стратегии фокусируется на глубине приверженности национального правительства искусственному интеллекту; исследуются обязательства по расходованию средств и национальные стратегии.
#
# Коммерческий индикатор фокусируется на уровне активности стартапов, инвестиций и бизнес-инициатив, основанных на искусственном интеллекте.

# %%
df=df.sort_values(by=['Talent'], ascending=False)
df
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 16                     India   45.27           33.91                  77.30
# 2             United Kingdom   39.65           71.43                  74.65
# 5                  Singapore   39.38           84.30                  43.15
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 33      United Arab Emirates    2.65           79.16                  72.12
# 43                    Mexico    1.72           41.85                  97.03
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 46                     Qatar    0.00           67.97                  62.58
#
# ...

# %%
X=df['Infrastructure']
Y=df['Talent']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Infrastructure', ylabel='Talent'>

# %%
X=df['Operating Environment']
Y=df['Talent']

# %%
sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Operating Environment', ylabel='Talent'>

# %%
X=df['Research']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Research', ylabel='Talent'>

# %%
X=df['Development']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Development', ylabel='Talent'>

# %%
X=df['Government Strategy']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Government Strategy', ylabel='Talent'>

# %%
X=df['Commercial']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Commercial', ylabel='Talent'>

# %%
X=df['Infrastructure']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Infrastructure', ylabel='Talent'>

# %%
df['Talent'].corr(df['Infrastructure'])
# Out:
# 0.46329684565698664

# %%
X=df['Operating Environment']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Operating Environment', ylabel='Talent'>

# %%
df['Talent'].corr(df['Operating Environment'])
# Out:
# 0.15930531636270917

# %%
X=df['Research']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Research', ylabel='Talent'>

# %%
df['Talent'].corr(df['Research'])
# Out:
# 0.8102545414231658

# %%
X=df['Development']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Development', ylabel='Talent'>

# %%
df['Talent'].corr(df['Development'])
# Out:
# 0.6829306504704317

# %%
X=df['Government Strategy']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Government Strategy', ylabel='Talent'>

# %%
df['Talent'].corr(df['Government Strategy'])
# Out:
# 0.3216578055784995

# %%
X=df['Commercial']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Commercial', ylabel='Talent'>

# %%
df['Talent'].corr(df['Commercial'])
# Out:
# 0.7950713492277023

# %%
df['Cluster']
# Out:
# 0             Power players
# 16                Waking up
# 2     Traditional champions
# 5              Rising stars
# 4              Rising stars
#               ...
# 33                Waking up
# 43                Waking up
# 58                  Nascent
# 59                  Nascent
# 46                Waking up
# Name: Cluster, Length: 62, dtype: object

# %%
lesion_type_dict = {
    'Nascent': 1,
    'Waking up': 2,
    'Rising stars': 3,
    'Traditional champions': 4,
    'Power players': 5
}
df['NCluster'] = df.Cluster.map(lesion_type_dict)
df['NCluster'] = df["NCluster"].astype(int)
df
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 16                     India   45.27           33.91                  77.30
# 2             United Kingdom   39.65           71.43                  74.65
# 5                  Singapore   39.38           84.30                  43.15
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 33      United Arab Emirates    2.65           79.16                  72.12
# 43                    Mexico    1.72           41.85                  97.03
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 46                     Qatar    0.00           67.97                  62.58
#
# ...

# %%
df['Income group']. nunique ()
# Out:
# 3

# %%
df=df.rename(columns={'Income group': 'Income'})
lesion_type_dict = {
    'Lower middle': 1,
    'Upper middle': 2,
    'High': 3,
}
df['Income'] = df.Income .map(lesion_type_dict)
df['Income'] = df["Income"].astype(int)

# %%
X=df['Income']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Income', ylabel='Talent'>

# %%
df['Income'].to_numpy()
df['Talent'].corr(df['Income'])
# Out:
# 0.32719004086412706

# %%
df['NCluster'].to_numpy()
df['Income'].corr(df['NCluster'])
# Out:
# 0.416333199893226

# %%
df['Income'].to_numpy()
df['Talent'].corr(df['Income'])

# %%
df.corr()
# Out:
# <ipython-input-96-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Talent  Infrastructure  Operating Environment  \
# Talent                 1.000000        0.463297               0.159305
# Infrastructure         0.463297        1.000000               0.413042
# Operating Environment  0.159305        0.413042               1.000000
# Research               0.810255        0.617192               0.197111
# Development            0.682931        0.509444               0.155285
# Government Strategy    0.321658        0.551934               0.399741
# Commercial             0.795071        0.379933               0.114281
# Total score            0.861969        0.716481               0.368566
# ...

# %%
X=df['NCluster']
Y=df['Talent']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='NCluster', ylabel='Talent'>

# %%
df['NCluster'].to_numpy()
df['Talent'].corr(df['NCluster'])
# Out:
# 0.6856859124656381

# %%
df=df.rename(columns={'Political regime': 'Political'})
df
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 16                     India   45.27           33.91                  77.30
# 2             United Kingdom   39.65           71.43                  74.65
# 5                  Singapore   39.38           84.30                  43.15
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 33      United Arab Emirates    2.65           79.16                  72.12
# 43                    Mexico    1.72           41.85                  97.03
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 46                     Qatar    0.00           67.97                  62.58
#
# ...

# %%
X=df['Infrastructure']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Infrastructure', ylabel='Development'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(55,55)})
sns.pairplot(df)
plt.show()

# %%
df['Development'].corr(df['Infrastructure'])
# Out:
# 0.5094438483897936

# %%
X=df['Operating Environment']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Operating Environment', ylabel='Development'>

# %%
df['Development'].corr(df['Operating Environment'])
# Out:
# 0.15528545986774053

# %%
X=df['Research']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Research', ylabel='Development'>

# %%
df['Development'].corr(df['Research'])
# Out:
# 0.8459118030351856

# %%
X=df['Talent']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Talent', ylabel='Development'>

# %%
df['Development'].corr(df['Talent'])
# Out:
# 0.6829306504704317

# %%
X=df['Government Strategy']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Government Strategy', ylabel='Development'>

# %%
df['Development'].corr(df['Government Strategy'])
# Out:
# 0.42406091489772113

# %%
X=df['Commercial']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='Commercial', ylabel='Development'>

# %%
df['Development'].corr(df['Commercial'])
# Out:
# 0.7759290241894362

# %%
X=df['NCluster']
Y=df['Development']

sns.scatterplot(x=X,y=Y)
# Out:
# <Axes: xlabel='NCluster', ylabel='Development'>

# %%
df['Development'].corr(df['NCluster'])
# Out:
# 0.7446676289181235
